# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib
import json
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

import warnings
warnings.filterwarnings("ignore")

from math import pi

from statsmodels.formula.api import ols

# %% [markdown]
# For storing our credentials, we'll create a file spotify_config.py

# %%
config = {
    'client_id' : 'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX',
    'client_secret' :'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX'
}

# %%
playlist_id='https://open.spotify.com/playlist/37i9dQZF1DZ06evO21GuFq?si=fe059fa75f4540de' #insert your playlist id
results = sp.playlist(playlist_id)

# %%
ids=[]

for item in results['tracks']['items']:
        track = item['track']['id']
        ids.append(track)
        
song_meta={'id':[],'album':[], 'name':[], 
           'artist':[],'explicit':[],'popularity':[]}

for song_id in ids:
    # get song's meta data
    meta = sp.track(song_id)
    
    # song id
    song_meta['id'].append(song_id)

    # album name
    album=meta['album']['name']
    song_meta['album']+=[album]

    # song name
    song=meta['name']
    song_meta['name']+=[song]
    
    # artists name
    s = ', '
    artist=s.join([singer_name['name'] for singer_name in meta['artists']])
    song_meta['artist']+=[artist]
    
    # explicit: lyrics could be considered offensive or unsuitable for children
    explicit=meta['explicit']
    song_meta['explicit'].append(explicit)
    
    # song popularity
    popularity=meta['popularity']
    song_meta['popularity'].append(popularity)

song_meta_df=pd.DataFrame.from_dict(song_meta)

# check the song feature
features = sp.audio_features(song_meta['id'])
# change dictionary to dataframe
features_df=pd.DataFrame.from_dict(features)

# convert milliseconds to mins
# duration_ms: The duration of the track in milliseconds.
# 1 minute = 60 seconds = 60 × 1000 milliseconds = 60,000 ms
features_df['duration_ms']=features_df['duration_ms']/60000

# combine two dataframe
final_df=song_meta_df.merge(features_df)
final_df
# Out:
#                         id                                 album  \
# 0   6ECBKSGhLYqLc2rafhN6VE                    Oi Meres Tou Fotos
# 1   5iq46N6lKkfqKT1HYi4T5I                       Eisitiria Dipla
# 2   5EaMEczDijEH2kA4gXYimA                        Mehri To Telos
# 3   5VuMQKHWECLFeaWCyj2e8n                I Epochi Tou Therismou
# 4   66YycWv7gAWOtwjUBXa1pH                              Synavlia
# 5   5O13C7CSJ1GuZFi8NhRzSc                     Giro Ap' Ton Ilio
# 6   5A6sSWNhJ5Lhx1vQCcNXmU                       Eisitiria Dipla
# 7   4CjX0qOTvodVLdeiHIyD0Q                I Epochi Tou Therismou
# 8   1vN8pzflHdy2qa5NMjAL2b                   Ekato Mikres Anases
# 9   3CqlgCreJdeLma3135Mpye                        Mehri To Telos
# 10  4gnoREo8FWiD5AezWo1r1Q                       Eisitiria Dipla
# 11  4MGsTph6Ty4yxYMabX1k9G                I Epochi Tou Therismou
# 12  6hPjtg4Ci4KfdpuIknjPYm                          Tria Mystika
# 13  4RnPmt1jGIzjtVAQVjgWW5                    Oi Meres Tou Fotos
# 14  6dvYXYUqxkyHx9jAqsFRJm                        Mehri To Telos
# 15  4l7XQ9BPOpDwAeBERGY13W                I Epochi Tou Therismou
# 16  1S5mFd6sGbcbzHysmVokSu                     Belle Reve (Live)
# 17  1g0RYc0T7bw5jWrRNBxQOS                    Oi Meres Tou Fotos
#
#    time_signature
# 0               4
# 1               3
# 2               4
# 3               4
# 4               4
# 5               4
# 6               5
# 7               4
# 8               4
# 9               5
# 10              4
# 11              4
# 12              4
# 13              5
# 14              4
# 15              3
# 16              4
# 17              4
# 18              4
# 19              4
# 20              4
# 21              4
# 22              4
# 23              4
# 24              4
# 25              4
# 26              4
# 27              4
# 28              4
# 29              4
# 30              4
# 31              3
# 32              4
# 33              4
# 34              4
# 35              1
# 36              4
# 37              4
# 38              4
# 39              4
# 40              4
# 41              4
# 42              4
# 43              4
# 44              4
# 45              4
# 46              4
# 47              4
# 48              4
#
# [49 rows x 23 columns]

# %%
final_df.isna().sum()
# Out:
# id                  0
# album               0
# name                0
# artist              0
# explicit            0
# popularity          0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# type                0
# uri                 0
# track_href          0
# analysis_url        0
# duration_ms         0
# time_signature      0
# dtype: int64

# %%
music_feature = features_df [['danceability','energy','loudness','speechiness','acousticness','instrumentalness',
                       'liveness', 'tempo', 'duration_ms', 'valence']]
music_feature.describe()
# Out:
#        danceability     energy   loudness  speechiness  acousticness  \
# count     49.000000  49.000000  49.000000    49.000000     49.000000
# mean       0.530245   0.430061  -8.987857     0.038480      0.480753
# std        0.103249   0.140499   2.464757     0.021927      0.293619
# min        0.214000   0.101000 -16.186000     0.023500      0.047400
# 25%        0.487000   0.325000 -10.420000     0.029400      0.194000
# 50%        0.528000   0.434000  -8.439000     0.033300      0.458000
# 75%        0.577000   0.525000  -7.243000     0.037400      0.708000
# max        0.774000   0.714000  -5.301000     0.158000      0.976000
#
#        instrumentalness   liveness       tempo  duration_ms    valence
# count         49.000000  49.000000   49.000000    49.000000  49.000000
# mean           0.001240   0.200020  117.804776     3.800959   0.347414
# std            0.005395   0.200082   27.190834     0.639438   0.163713
# min            0.000000   0.076300   62.302000     2.097117   0.057300
# 25%            0.000000   0.096800   96.024000     3.320033   0.219000
# 50%            0.000026   0.118000  120.040000     3.721333   0.322000
# 75%            0.000187   0.165000  135.894000     4.310667   0.447000
# max            0.037400   0.826000  180.930000     5.502450   0.776000

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()
music_feature.loc[:]=min_max_scaler.fit_transform(music_feature.loc[:])

# %%
music_feature
# Out:
#     danceability    energy  loudness  speechiness  acousticness  \
# 0       0.571429  0.469821  0.843454     0.024535      0.612320
# 1       0.555357  0.703100  0.971153     0.031227      0.757700
# 2       0.551786  0.402936  0.711713     0.045353      0.644626
# 3       0.644643  0.535073  0.692421     0.000000      0.000108
# 4       0.546429  0.647635  0.825356     0.046097      0.400172
# 5       0.680357  0.691680  0.757281     0.011896      0.334482
# 6       0.000000  0.435563  0.780064     0.084015      0.951540
# 7       0.776786  0.543230  0.752963     0.023792      0.001615
# 8       0.692857  0.561175  0.723013     0.023792      0.133104
# 9       0.983929  0.626427  0.735783     0.084758      0.157872
# 10      0.842857  0.889070  1.000000     0.103346      0.569244
# 11      0.814286  0.401305  0.499127     0.072862      0.366789
# 12      0.558929  0.539967  0.623243     0.047584      0.417403
# 13      0.575000  0.557912  0.902710     0.067658      0.628473
# 14      0.625000  0.313214  0.672393     0.085502      0.865389
# 15      0.648214  0.177814  0.505926     0.069145      0.870773
# 16      0.603571  0.319739  0.454938     0.057993      0.196640
# 17      0.641071  0.711256  0.760312     0.014870      0.073875
# 18      0.683929  0.344209  0.440514     0.023792      0.762007
# 19      0.498214  0.615008  0.816996     0.024535      0.000000
# 21          0.000000  0.182340  0.174090     0.395913  0.707806
# 22          0.000687  0.030012  0.636899     0.532381  0.000000
# 23          0.000000  0.056956  0.535582     0.514159  0.467093
# 24          0.000722  0.118314  0.250270     0.344832  0.224990
# 25          0.003075  1.000000  0.574645     0.980746  0.013497
# 26          0.000000  0.007069  0.486715     0.381314  0.654933
# 27          0.002642  0.039616  0.000000     0.606431  0.124809
# 28          0.001476  0.218354  0.232778     0.303641  0.151245
# 29          0.001727  0.838602  0.139402     0.650024  0.355781
# 30          0.001690  0.020542  0.657206     0.382341  0.174899
# 31          0.004492  0.051621  0.980055     0.359118  0.593711
# 32          0.001794  0.017740  0.386334     0.452491  0.354390
# 33          0.000000  0.020408  0.798049     0.596765  0.300125
# 34          1.000000  0.002268  1.000000     0.413792  0.542229
# 35          0.022914  0.011204  0.242076     1.000000  0.212467
# 36          0.000000  0.054288  0.315507     0.579415  0.251426
# 37          0.012540  0.091637  0.636317     0.542350  0.245861
# 38          0.018690  0.123649  0.630888     0.692458  0.191596
# 39          0.000000  0.048953  0.519119     0.351351  0.961041
# 40          0.084759  0.814593  0.551337     0.687940  0.689718
# 41          0.000826  0.042284  0.569157     0.761090  0.174899
# 42          0.000000  0.059624  0.620359     0.444744  0.458745
# 43          0.011230  0.031613  0.575969     0.000000  0.643801
# 44          0.000000  0.853275  0.713887     0.329938  0.518575
# 45          0.127807  0.011738  0.410468     0.663063  0.442048
# 46          0.000000  0.000000  0.927698     0.287735  0.570057
# 47          0.000000  0.289049  0.233587     0.282953  0.685543
# 48          0.010374  0.064959  0.098687     0.214135  0.454571

# %%
# plot size
fig=plt.figure(figsize=(12,8))

# convert column names into a list
categories=list(music_feature.columns)
# number of categories
N=len(categories)

# create a list with the average of all features
value=list(music_feature.mean())

# repeat first value to close the circle
# the plot is a circle, so we need to "complete the loop"
# and append the start value to the end.
value+=value[:1]
# calculate angle for each category
angles=[n/float(N)*2*pi for n in range(N)]
angles+=angles[:1]

# plot
plt.polar(angles, value)
plt.fill(angles,value,alpha=0.3)

# plt.title('Discovery Weekly Songs Audio Features', size=35)

plt.xticks(angles[:-1],categories, size=15)
plt.yticks(color='grey',size=15)
plt.show()

# %%
corr_table = music_feature.corr(method="pearson")
corr_table.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_ca48a_row0_col0, #T_ca48a_row1_col1, #T_ca48a_row2_col2, #T_ca48a_row3_col3, #T_ca48a_row4_col4, #T_ca48a_row5_col5, #T_ca48a_row6_col6, #T_ca48a_row7_col7, #T_ca48a_row8_col8, #T_ca48a_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ca48a_row0_col1, #T_ca48a_row6_col1 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_ca48a_row0_col2 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_ca48a_row0_col3 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_ca48a_row0_col4, #T_ca48a_row7_col6, #T_ca48a_row9_col7 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_ca48a_row0_col5 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_ca48a_row0_col6 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_ca48a_row0_col7, #T_ca48a_row1_col0, #T_ca48a_row8_col1 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_ca48a_row0_col8 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_ca48a_row0_col9 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_ca48a_row1_col2 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_ca48a_row1_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_ca48a_row1_col4, #T_ca48a_row2_col3, #T_ca48a_row2_col5, #T_ca48a_row3_col2, #T_ca48a_row4_col0, #T_ca48a_row4_col1, #T_ca48a_row4_col6, #T_ca48a_row4_col7, #T_ca48a_row6_col0, #T_ca48a_row8_col0, #T_ca48a_row8_col9, #T_ca48a_row9_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ca48a_row1_col5 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_ca48a_row1_col6 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_ca48a_row1_col7, #T_ca48a_row1_col8, #T_ca48a_row6_col2 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_ca48a_row1_col9 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_ca48a_row2_col0, #T_ca48a_row7_col2 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_ca48a_row2_col1 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_ca48a_row2_col4 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_ca48a_row2_col6, #T_ca48a_row9_col6 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_ca48a_row2_col7 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_ca48a_row2_col8, #T_ca48a_row5_col8 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_ca48a_row2_col9, #T_ca48a_row7_col1 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_ca48a_row3_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_ca48a_row3_col1, #T_ca48a_row4_col3 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_ca48a_row3_col4 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_ca48a_row3_col5 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_ca48a_row3_col6 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_ca48a_row3_col7, #T_ca48a_row7_col4, #T_ca48a_row9_col5 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_ca48a_row3_col8 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_ca48a_row3_col9, #T_ca48a_row6_col3 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_ca48a_row4_col2 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_ca48a_row4_col5 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_ca48a_row4_col8 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_ca48a_row4_col9 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_ca48a_row5_col0 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_ca48a_row5_col1, #T_ca48a_row7_col8, #T_ca48a_row9_col4 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_ca48a_row5_col2 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_ca48a_row5_col3 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_ca48a_row5_col4 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_ca48a_row5_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_ca48a_row5_col7 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_ca48a_row5_col9 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_ca48a_row6_col4 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_ca48a_row6_col5 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_ca48a_row6_col7 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_ca48a_row6_col8 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_ca48a_row6_col9 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_ca48a_row7_col0 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_ca48a_row7_col3 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_ca48a_row7_col5 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_ca48a_row7_col9 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_ca48a_row8_col2 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_ca48a_row8_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_ca48a_row8_col4 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_ca48a_row8_col5 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_ca48a_row8_col6 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_ca48a_row8_col7 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_ca48a_row9_col0 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_ca48a_row9_col1 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_ca48a_row9_col2 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_ca48a_row9_col3 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# </style>
# <table id="T_ca48a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >danceability</th>
#       <th class="col_heading level0 col1" >energy</th>
#       <th class="col_heading level0 col2" >loudness</th>
#       <th class="col_heading level0 col3" >speechiness</th>
#       <th class="col_heading level0 col4" >acousticness</th>
#       <th class="col_heading level0 col5" >instrumentalness</th>
#       <th class="col_heading level0 col6" >liveness</th>
#       <th class="col_heading level0 col7" >tempo</th>
#       <th class="col_heading level0 col8" >duration_ms</th>
#       <th class="col_heading level0 col9" >valence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca48a_level0_row0" class="row_heading level0 row0" >danceability</th>
#       <td id="T_ca48a_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ca48a_row0_col1" class="data row0 col1" >0.177940</td>
#       <td id="T_ca48a_row0_col2" class="data row0 col2" >0.105418</td>
#       <td id="T_ca48a_row0_col3" class="data row0 col3" >-0.157301</td>
#       <td id="T_ca48a_row0_col4" class="data row0 col4" >-0.215718</td>
#       <td id="T_ca48a_row0_col5" class="data row0 col5" >0.009015</td>
#       <td id="T_ca48a_row0_col6" class="data row0 col6" >-0.216584</td>
#       <td id="T_ca48a_row0_col7" class="data row0 col7" >0.191669</td>
#       <td id="T_ca48a_row0_col8" class="data row0 col8" >-0.214711</td>
#       <td id="T_ca48a_row0_col9" class="data row0 col9" >0.420559</td>
#     </tr>
#     <tr>
#       <th id="T_ca48a_level0_row1" class="row_heading level0 row1" >energy</th>
#       <td id="T_ca48a_row1_col0" class="data row1 col0" >0.177940</td>
#       <td id="T_ca48a_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_ca48a_row1_col2" class="data row1 col2" >0.668279</td>
#       <td id="T_ca48a_row1_col3" class="data row1 col3" >0.000156</td>
#       <td id="T_ca48a_row1_col4" class="data row1 col4" >-0.621387</td>
#       <td id="T_ca48a_row1_col5" class="data row1 col5" >-0.128543</td>
#       <td id="T_ca48a_row1_col6" class="data row1 col6" >0.180771</td>
#       <td id="T_ca48a_row1_col7" class="data row1 col7" >0.091879</td>
#       <td id="T_ca48a_row1_col8" class="data row1 col8" >-0.090294</td>
#       <td id="T_ca48a_row1_col9" class="data row1 col9" >0.418082</td>
#     </tr>
#     <tr>
#       <th id="T_ca48a_level0_row2" class="row_heading level0 row2" >loudness</th>
#       <td id="T_ca48a_row2_col0" class="data row2 col0" >0.105418</td>
#       <td id="T_ca48a_row2_col1" class="data row2 col1" >0.668279</td>
#       <td id="T_ca48a_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_ca48a_row2_col3" class="data row2 col3" >-0.365679</td>
#       <td id="T_ca48a_row2_col4" class="data row2 col4" >-0.286276</td>
#       <td id="T_ca48a_row2_col5" cla

# %%
music_feature.corrwith(music_feature["valence"]).sort_values(ascending=False)
# Out:
# valence             1.000000
# danceability        0.420559
# energy              0.418082
# loudness            0.194658
# speechiness         0.186875
# tempo               0.101928
# instrumentalness    0.098643
# liveness           -0.027638
# acousticness       -0.129289
# duration_ms        -0.440670
# dtype: float64

# %%
music_feature['valence'].plot()
plt.ylabel("Valence")
# Out:
# Text(0, 0.5, 'Valence')

# %%
music_feature['valence'].plot(style='k.',kind='hist')
plt.title('Hisogram of valence')
plt.show()

# %%
music_feature['valence'].mean()
# Out:
# 0.4036653481484427

# %%
fig, axes = plt.subplots(1,2)
axes[0].scatter(final_df['valence'], final_df['valence'])
axes[0].set_title("Original data")
axes[1].scatter(music_feature['valence'], music_feature['valence'])
axes[1].set_title("MinMax scaled data")
plt.show()

# %%
X = music_feature[['danceability', 'energy', 'speechiness', 'liveness', 'acousticness', 'instrumentalness', 'duration_ms']]
#X = music_feature[['danceability', 'energy', 'speechiness', 'liveness']]
y = music_feature['valence']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, shuffle=False)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (34, 7)
# (34,)
# (15, 7)
# (15,)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import roc_curve, roc_auc_score, classification_report, accuracy_score, confusion_matrix 
from sklearn.metrics import mean_squared_error, mean_absolute_error, classification_report,r2_score
import sklearn.metrics as metrics

# %%
cv = KFold(n_splits=5, random_state=1, shuffle=True)
linReg = LinearRegression()
scores = cross_val_score(linReg, X, y, scoring='r2', cv=cv, n_jobs=1)
scores
# Out:
# array([-0.17414955,  0.46671084,  0.08827451,  0.16963938, -0.0975591 ])

# %%
predicted = cross_val_predict(linReg, X, y, cv=6)
scores = cross_val_score(linReg, X, y, scoring='r2', cv=12, n_jobs=1)
scores
# Out:
# array([ 0.59270847,  0.48286623,  0.21267911, -0.52006972, -3.6696779 ,
#         0.23884591, -0.21194081,  0.23373247, -4.5373253 ,  0.28965756,
#        -1.95910885, -5.49012447])

# %%
fig,ax = plt.subplots()
ax.scatter(y, predicted, edgecolors=(1, 1, 1))
ax.plot([y.min(), y.max()], [y.min(), y.max()], color='red')
ax.set_xlabel('Expected ')
ax.set_ylabel('Predicted ')
plt.show()

# %%
fig,ax = plt.subplots()
plt.plot(scores)
ax.set_xlabel('Folds')
ax.set_ylabel('R2 score')
plt.show()

# %%
kf = KFold(n_splits=10, shuffle=True)
scores = []
errors = []
i = 1

for training, testing in kf.split(X, y):
    X_train, X_test = X.loc[training], X.loc[testing]
    y_train, y_test = y.loc[training], y.loc[testing]
    print ('{}/10 Folds {}'.format(i, kf.n_splits))
    print('--------------------------')
    
    linReg = LinearRegression()
    linReg.fit(X_train, y_train)
    score = metrics.r2_score(y_test, linReg.predict(X_test))
    error = metrics.mean_squared_error(y_test, linReg.predict(X_test))
    print('R2 Score: ', score)
    print('MSE: ', error)
    scores.append(score)
    errors.append(error)
    print('\n')
    i += 1
# Out:
# 1/10 Folds 10
# --------------------------
# R2 Score:  -0.4347808734381664
# MSE:  0.018267474491309024
#
#
# 2/10 Folds 10
# --------------------------
# R2 Score:  0.11293672565875668
# MSE:  0.06954217539954076
#
#
# 3/10 Folds 10
# --------------------------
# R2 Score:  -7.9392587752952295
# MSE:  0.09162966400116732
#
#
# 4/10 Folds 10
# --------------------------
# R2 Score:  0.2191040517767846
# MSE:  0.07576513954004012
#
#
# 5/10 Folds 10
# --------------------------
# R2 Score:  0.4945576194369521
# MSE:  0.012950088764795434
#
#
# 6/10 Folds 10
# --------------------------
# R2 Score:  -0.27863835835301676
# MSE:  0.03661631534601718
#
#
# 7/10 Folds 10
# --------------------------
# R2 Score:  -0.12151611944489527
# MSE:  0.05888697347947619
#
#
# 8/10 Folds 10
# --------------------------
# R2 Score:  0.24241384633464935
# MSE:  0.017287870319128477
#
#
# 9/10 Folds 10
# --------------------------
# R2 Score:  0.7409922486276795
# MSE:  0.014023503313467
#
#
# 10/10 Folds 10
# --------------------------
# R2 Score:  -8.422742693686427
# MSE:  0.08910957736618155

# %%
fig, ax = plt.subplots()
plt.plot(errors)
ax.set_xlabel('Folds')
ax.set_ylabel('Errors')
plt.show()

# %%
print("Coefficients: \n", linReg.coef_)
print("Intercept: \n", linReg.intercept_)
# Out:
# Coefficients:
#  [ 0.46165309  0.54457634  0.13287977  0.10928104  0.2461794   0.9291325
#  -0.32424124]
# Intercept:
#  -0.15836477959715245

# %%
y_pred_lin = linReg.predict(X_test)
dfp = pd.DataFrame({'Actual_Price': y_test, 'Predicted_Price': y_pred_lin})
dfp.head()
# Out:
#     Actual_Price  Predicted_Price
# 3       0.339084         0.283652
# 23      0.467093         0.323411
# 33      0.300125         0.280794
# 34      0.542229         1.118725

# %%
plt.scatter(dfp['Actual_Price'], dfp['Predicted_Price'])

# %%
reg_score = linReg.score(X_test, y_test)
print("Linear Regression Score: ", reg_score)
print("Absolute Squared Error: ", mean_absolute_error(y_test, y_pred_lin))
mse_lin = mean_squared_error(y_test, y_pred_lin)
print("Mean Squared Error: ", mse_lin)
# Out:
# Linear Regression Score:  -8.422742693686427
# Absolute Squared Error:  0.19873550607542015
# Mean Squared Error:  0.08910957736618155
